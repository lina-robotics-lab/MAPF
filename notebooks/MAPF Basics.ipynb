# %%
import networkx as nx
import numpy as np
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = nx.circulant_graph(10,offsets = [0,1])
nx.draw_networkx(G)

# %%
# Basic components of the MAPF problem

G # The graph

start_nodes = [0,9]

goal_nodes = [4,5]

assert(len(start_nodes)==len(goal_nodes))

n_agent = len(start_nodes)

'''
    If the problem is labeled, the goals are pre-assigned to the agents, meaning agent k must go to goal k. 
    Otherwise, the goals are not pre-assigned to the agents, meaning the problem is considered solved if all goals are occupied by the agents.
'''
labeled_goals = True

# %%
'''
Basic Components of the Single-agent Path Finding problem with space-time constraints.

* The graph: G
* The starting node: start
* The goal node: goal
* Node constraints with time-stamp: (t,s), meaning the agent cannot be at node s at time step t.
* Edge constraints with time-stamp: (t,(s,sp)), meaning the agent cannot traverse the edge (s,sp) from time step t to t+1. More explicitly, if the agent is at node s at time step t, it is not allowed to enter sp at the next time step.
* Objective: minimize the number of time steps to reach the goal.

'''
